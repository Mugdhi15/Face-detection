# %% [markdown]
# <a href="https://colab.research.google.com/github/Mugdhi15/Face-detection/blob/main/face_detection_using_DeepFace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install deepface &> /dev/null  #inbuilt function to nullify all the unnecessary messages
print("deep face installed successfully")
# Out:
# deep face installed successfully

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
img1=cv2.imread("/content/drive/MyDrive/Colab Notebooks/happy me.jpeg")
plt.imshow(img1)
plt.imshow(img1[:, :, ::-1])
plt.show()

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
img2=cv2.imread("/content/drive/MyDrive/Colab Notebooks/IMG_6802.JPG")
plt.imshow(img2)
plt.imshow(img2[:, :, ::-1])
plt.show()

# %%
obj=DeepFace.analyze(img2, actions=['age','gender','race','emotion'])
print(obj)
# Out:
# ...
# Action: emotion: 100%|██████████| 4/4 [00:05<00:00,  1.29s/it]
# {'age': 31, 'region': {'x': 287, 'y': 382, 'w': 643, 'h': 643}, 'gender': 'Woman', 'race': {'asian': 11.243659257888794, 'indian': 30.041542649269104, 'black': 2.483987435698509, 'white': 6.662105023860931, 'middle eastern': 4.592010751366615, 'latino hispanic': 44.976696372032166}, 'dominant_race': 'latino hispanic', 'emotion': {'angry': 22.74917350704512, 'disgust': 0.0009918507794299627, 'fear': 5.329837967743752, 'happy': 0.0008812361172683179, 'sad': 67.10536879929118, 'surprise': 0.01927632225787698, 'neutral': 4.79447125163503}, 'dominant_emotion': 'sad'}

# %%
#print result img2
print("your age is",obj['age'], "\nyour gender is",obj['gender'],"\nyour race is",obj['race'], "\nyour emotion is", obj['emotion'])
# Out:
# your age is 31
# your gender is Woman
# your race is {'asian': 11.243659257888794, 'indian': 30.041542649269104, 'black': 2.483987435698509, 'white': 6.662105023860931, 'middle eastern': 4.592010751366615, 'latino hispanic': 44.976696372032166}
# your emotion is {'angry': 22.74917350704512, 'disgust': 0.0009918507794299627, 'fear': 5.329837967743752, 'happy': 0.0008812361172683179, 'sad': 67.10536879929118, 'surprise': 0.01927632225787698, 'neutral': 4.79447125163503}

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
img3=cv2.imread("/content/drive/MyDrive/Colab Notebooks/angry me.jpeg")
plt.imshow(img3)
plt.imshow(img3[:, :, ::-1])
plt.show()

# %%
print("your age is",obj['age'], "\nyour gender is",obj['gender'],"\nyour race is",obj['race'], "\nyour emotion is", obj['emotion'])
# Out:
# your age is 31
# your gender is Woman
# your race is {'asian': 11.243659257888794, 'indian': 30.041542649269104, 'black': 2.483987435698509, 'white': 6.662105023860931, 'middle eastern': 4.592010751366615, 'latino hispanic': 44.976696372032166}
# your emotion is {'angry': 22.74917350704512, 'disgust': 0.0009918507794299627, 'fear': 5.329837967743752, 'happy': 0.0008812361172683179, 'sad': 67.10536879929118, 'surprise': 0.01927632225787698, 'neutral': 4.79447125163503}

# %% [markdown]
# #flipping the color from BGR to BGB format

# %%
plt.imshow(img1[:, :, ::-1])
plt.show()

# %%
#analyse image'
obj=DeepFace.analyze(img1, actions=['age','gender','race','emotion'])
print(obj)
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 77.7MB/s]
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
# 100%|██████████| 539M/539M [00:07<00:00, 67.5MB/s]
# gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: /root/.deepface/weights/gender_model_weights.h5
# 100%|██████████| 537M/537M [00:04<00:00, 113MB/s]
# race_model_single_batch.h5 will be downloaded...
# Downloading...
# ...

# %%
print("your age is",obj['age'], "\nyour gender is",obj['gender'],"\nyour race is",obj['race'], "\nyour emotion is", obj['emotion'])
# Out:
# your age is 32
# your gender is Woman
# your race is {'asian': 33.75449180603027, 'indian': 23.142459988594055, 'black': 10.399454832077026, 'white': 4.742623493075371, 'middle eastern': 3.247465193271637, 'latino hispanic': 24.713513255119324}
# your emotion is {'angry': 0.0011804551334311188, 'disgust': 1.2356717730374652e-06, 'fear': 0.006989241122852207, 'happy': 90.40749783426548, 'sad': 0.058634327719738755, 'surprise': 0.08828234388479961, 'neutral': 9.437418349096971}

# %% [markdown]
#  #to see what other features this function has

# %%
DeepFace?

# %%
#print result img1
print("your age is",obj['age'], "\nyour gender is",obj['gender'],"\nyour race is",obj['race'], "\nyour emotion is", obj['emotion'])
# Out:
# your age is 32
# your gender is Woman
# your race is {'asian': 33.75449180603027, 'indian': 23.142459988594055, 'black': 10.399454832077026, 'white': 4.742623493075371, 'middle eastern': 3.247465193271637, 'latino hispanic': 24.713513255119324}
# your emotion is {'angry': 0.0011804551334311188, 'disgust': 1.2356717730374652e-06, 'fear': 0.006989241122852207, 'happy': 90.40749783426548, 'sad': 0.058634327719738755, 'surprise': 0.08828234388479961, 'neutral': 9.437418349096971}

# %%
obj=DeepFace.analyze(img2, actions=['age','gender','race','emotion'])
print(obj)
# Out:
# ...
# Action: emotion: 100%|██████████| 4/4 [00:02<00:00,  1.70it/s]
# {'age': 29, 'region': {'x': 133, 'y': 114, 'w': 299, 'h': 299}, 'gender': 'Woman', 'race': {'asian': 9.961897879838943, 'indian': 55.61650991439819, 'black': 7.064001262187958, 'white': 3.859974443912506, 'middle eastern': 3.7121810019016266, 'latino hispanic': 19.785431027412415}, 'dominant_race': 'indian', 'emotion': {'angry': 2.0741309344250523, 'disgust': 7.641126587276514e-06, 'fear': 0.6809592652892629, 'happy': 7.521876334934575e-05, 'sad': 17.660419205452158, 'surprise': 0.0015746049968523158, 'neutral': 79.58283302681643}, 'dominant_emotion': 'neutral'}

# %%
print("your age is",obj['age'], "your gender is",obj['gender'],"your race is",obj['race'], "your emotion is", obj['emotion'])
# Out:
# your age is 29 your gender is Woman your race is {'asian': 40.835583209991455, 'indian': 26.199299097061157, 'black': 7.432907074689865, 'white': 3.2920215278863907, 'middle eastern': 1.8531646579504013, 'latino hispanic': 20.38702815771103} your emotion is {'angry': 7.754383236169815, 'disgust': 0.00015207905335046235, 'fear': 0.3886837512254715, 'happy': 0.10950047289952636, 'sad': 1.1272811330854893, 'surprise': 0.21590536925941706, 'neutral': 90.40409922599792}

# %%
obj=DeepFace.analyze(img3, actions=['age','gender','race','emotion'])
print(obj)
# Out:
# ...
# Action: emotion: 100%|██████████| 4/4 [00:02<00:00,  1.56it/s]
# {'age': 32, 'region': {'x': 136, 'y': 189, 'w': 297, 'h': 297}, 'gender': 'Woman', 'race': {'asian': 34.026166796684265, 'indian': 18.39737743139267, 'black': 9.940700978040695, 'white': 8.481068164110184, 'middle eastern': 6.3460491597652435, 'latino hispanic': 22.808639705181122}, 'dominant_race': 'asian', 'emotion': {'angry': 63.768879399828876, 'disgust': 0.018026686649497546, 'fear': 5.429822530139836, 'happy': 0.40663068743829056, 'sad': 6.709080589358842, 'surprise': 0.8988574682985228, 'neutral': 22.768708930534657}, 'dominant_emotion': 'angry'}

# %%
print("your age is",obj['age'], "\nyour gender is",obj['gender'],"\nyour race is",obj['race'], "\nyour emotion is", obj['emotion'])
# Out:
# your age is 32
# your gender is Woman
# your race is {'asian': 34.026166796684265, 'indian': 18.39737743139267, 'black': 9.940700978040695, 'white': 8.481068164110184, 'middle eastern': 6.3460491597652435, 'latino hispanic': 22.808639705181122}
# your emotion is {'angry': 63.768879399828876, 'disgust': 0.018026686649497546, 'fear': 5.429822530139836, 'happy': 0.40663068743829056, 'sad': 6.709080589358842, 'surprise': 0.8988574682985228, 'neutral': 22.768708930534657}

# %%
obj=DeepFace.analyze(img2, actions=['age','gender','race','emotion'])
print(obj)
# Out:
# ...
# Action: emotion: 100%|██████████| 4/4 [00:02<00:00,  1.69it/s]
# {'age': 29, 'region': {'x': 133, 'y': 114, 'w': 299, 'h': 299}, 'gender': 'Woman', 'race': {'asian': 9.961897879838943, 'indian': 55.61650991439819, 'black': 7.064001262187958, 'white': 3.859974443912506, 'middle eastern': 3.7121810019016266, 'latino hispanic': 19.785431027412415}, 'dominant_race': 'indian', 'emotion': {'angry': 2.0741309344250523, 'disgust': 7.641126587276514e-06, 'fear': 0.6809592652892629, 'happy': 7.521876334934575e-05, 'sad': 17.660419205452158, 'surprise': 0.0015746049968523158, 'neutral': 79.58283302681643}, 'dominant_emotion': 'neutral'}
